# %% [markdown]
# # PhonePe Data Collection

# %% [markdown]
# ## Libraries

# %%
# Required libraries
import pandas as pd
import os
import json
import pprint

# %% [markdown]
# ## Data Fetching

# %%
# Aggregated-Transaction
path = "pulse/data/aggregated/transaction/country/india/state/"

Agg_state_list = os.listdir(path)
Agg_state_list

clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i = path + i + "/"
    Agg_yr_list = os.listdir(p_i)
    for j in Agg_yr_list:
        p_j = p_i + j + "/"
        Agg_Q_list = os.listdir(p_j)
        for k in Agg_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            for z in D['data']['transactionData']:
                Name = z['name']
                count = z['paymentInstruments'][0]['count']
                amount = z['paymentInstruments'][0]['amount']
                clm['Transaction_type'].append(Name)
                clm['Transaction_count'].append(count)
                clm['Transaction_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans = pd.DataFrame(clm)

# %%
Agg_Trans.to_csv("Agg_Trans.csv", encoding='utf-8', index=False)

# %%
Agg_Trans
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 4309                west-bengal  2023       4         Merchant payments
# 4310                west-bengal  2023       4     Peer-to-peer payments
# 4311                west-bengal  2023       4  Recharge & bill payments
# 4312                west-bengal  2023       4        Financial Services
# 4313                west-bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
# Aggregated-User
path = "pulse/data/aggregated/user/country/india/state/"

Agg_state_list = os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Registered_users':[], 'App_opens':[], 'Device_Brand':[], 'Brand_users':[], 'Device_share':[]}

for i in Agg_state_list:
    p_i = path + i + "/"
    Agg_yr_list = os.listdir(p_i)
    for j in Agg_yr_list:
        p_j = p_i + j + "/"
        Agg_Q_list = os.listdir(p_j)
        for k in Agg_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            if D["data"]["usersByDevice"] is not None:
                for z in D["data"]["usersByDevice"]:
                    users = D["data"]["aggregated"]["registeredUsers"]
                    usage = D["data"]["aggregated"]["appOpens"]
                    Brand = z['brand']
                    Count = z['count']
                    percent = z['percentage']
                    clm['Registered_users'].append(users)
                    clm['App_opens'].append(usage)
                    clm['Device_Brand'].append(Brand)
                    clm['Brand_users'].append(Count)
                    clm['Device_share'].append(percent)
                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Users = pd.DataFrame(clm)

# %%
Agg_Users.to_csv("Agg_Users.csv", encoding='utf-8', index=False)

# %%
Agg_Users
# Out:
#                           State  Year  Quater  Registered_users  App_opens  \
# 0     andaman-&-nicobar-islands  2018       1              6740          0
# 1     andaman-&-nicobar-islands  2018       1              6740          0
# 2     andaman-&-nicobar-islands  2018       1              6740          0
# 3     andaman-&-nicobar-islands  2018       1              6740          0
# 4     andaman-&-nicobar-islands  2018       1              6740          0
# ...                         ...   ...     ...               ...        ...
# 6727                west-bengal  2022       1          21919787  236131065
# 6728                west-bengal  2022       1          21919787  236131065
# 6729                west-bengal  2022       1          21919787  236131065
# 6730                west-bengal  2022       1          21919787  236131065
# 6731                west-bengal  2022       1          21919787  236131065
#
#      Device_Brand  Brand_users  Device_share
# ...

# %%
# Aggregated-Insurance
path = "pulse/data/aggregated/insurance/country/india/state/"

Agg_state_list = os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i = path + i + "/"
    Agg_yr_list = os.listdir(p_i)
    for j in Agg_yr_list:
        p_j = p_i + j + "/"
        Agg_Q_list = os.listdir(p_j)
        for k in Agg_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            for z in D['data']['transactionData']:
                count = z['paymentInstruments'][0]['count']
                amount = z['paymentInstruments'][0]['amount']
                clm['Insurance_count'].append(count)
                clm['Insurance_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Ins = pd.DataFrame(clm)

# %%
Agg_Ins.to_csv("Agg_Ins.csv", encoding='utf-8', index=False)

# %%
Agg_Ins
# Out:
#                          State  Year  Quater  Insurance_count  \
# 0    andaman-&-nicobar-islands  2020       2                6
# 1    andaman-&-nicobar-islands  2020       3               41
# 2    andaman-&-nicobar-islands  2020       4              124
# 3    andaman-&-nicobar-islands  2021       1              225
# 4    andaman-&-nicobar-islands  2021       2              137
# ..                         ...   ...     ...              ...
# 533                west-bengal  2022       4            54277
# 534                west-bengal  2023       1            56833
# 535                west-bengal  2023       2            49792
# 536                west-bengal  2023       3            58131
# 537                west-bengal  2023       4            72712
#
#      Insurance_amount
# 0              1360.0
# 1             15380.0
# 2            157975.0
# 3            244266.0
# 4            181504.0
# ..                ...
# 533        70466433.0
# 534        77461732.0
# ...

# %%
# Map-Transaction
path = "pulse/data/map/transaction/hover/country/india/state/"

Map_state_list = os.listdir(path)

clm={'State':[], 'District':[], 'Year':[], 'Quater':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Map_state_list:
    p_i = path + i + "/"
    Map_yr_list = os.listdir(p_i)
    for j in Map_yr_list:
        p_j = p_i + j + "/"
        Map_Q_list = os.listdir(p_j)
        for k in Map_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            for z in D['data']['hoverDataList']:
                place = z['name']
                count = z['metric'][0]['count']
                amount = z['metric'][0]['amount']
                clm['District'].append(place)
                clm['Transaction_count'].append(count)
                clm['Transaction_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Trans = pd.DataFrame(clm)

# %%
Map_Trans.to_csv("Map_Trans.csv", encoding='utf-8', index=False)

# %%
Map_Trans
# Out:
#                            State                           District  Year  \
# 0      andaman-&-nicobar-islands  north and middle andaman district  2018
# 1      andaman-&-nicobar-islands             south andaman district  2018
# 2      andaman-&-nicobar-islands                  nicobars district  2018
# 3      andaman-&-nicobar-islands  north and middle andaman district  2018
# 4      andaman-&-nicobar-islands             south andaman district  2018
# ...                          ...                                ...   ...
# 17559                west-bengal                     nadia district  2023
# 17560                west-bengal                   birbhum district  2023
# 17561                west-bengal           purba medinipur district  2023
# 17562                west-bengal                    maldah district  2023
# 17563                west-bengal                 darjiling district  2023
#
#        Quater  Transaction_count  Transaction_amount
# ...

# %%
# Map-User
path = "pulse/data/map/user/hover/country/india/state/"

Map_state_list = os.listdir(path)

clm={'State':[], 'District':[], 'Year':[],'Quater':[],'Registered_users':[], 'App_opens':[]}

for i in Map_state_list:
    p_i = path + i + "/"
    Map_yr_list = os.listdir(p_i)
    for j in Map_yr_list:
        p_j = p_i + j + "/"
        Map_Q_list = os.listdir(p_j)
        for k in Map_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            for z in D["data"]["hoverData"]:
                place = z
                users = D["data"]["hoverData"][f"{place}"]["registeredUsers"]
                usage = D["data"]["hoverData"][f"{place}"]["appOpens"]
                clm['Registered_users'].append(users)
                clm['App_opens'].append(usage)
                clm['District'].append(place)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Users = pd.DataFrame(clm)

# %%
Map_Users.to_csv("Map_Users.csv", encoding='utf-8', index=False)

# %%
Map_Users
# Out:
#                            State                           District  Year  \
# 0      andaman-&-nicobar-islands  north and middle andaman district  2018
# 1      andaman-&-nicobar-islands             south andaman district  2018
# 2      andaman-&-nicobar-islands                  nicobars district  2018
# 3      andaman-&-nicobar-islands  north and middle andaman district  2018
# 4      andaman-&-nicobar-islands             south andaman district  2018
# ...                          ...                                ...   ...
# 17563                west-bengal                     nadia district  2023
# 17564                west-bengal                   birbhum district  2023
# 17565                west-bengal           purba medinipur district  2023
# 17566                west-bengal                    maldah district  2023
# 17567                west-bengal                 darjiling district  2023
#
#        Quater  Registered_users  App_opens
# ...

# %%
# Map-Insurance
path = "pulse/data/map/insurance/hover/country/india/state/"

Map_state_list = os.listdir(path)

clm={'State':[], 'District':[], 'Year':[],'Quater':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Map_state_list:
    p_i = path + i + "/"
    Map_yr_list = os.listdir(p_i)
    for j in Map_yr_list:
        p_j = p_i + j + "/"
        Map_Q_list = os.listdir(p_j)
        for k in Map_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            for z in D['data']['hoverDataList']:
                place = z["name"]
                count = z['metric'][0]['count']
                amount = z['metric'][0]['amount']
                clm['Insurance_count'].append(count)
                clm['Insurance_amount'].append(amount)
                clm['District'].append(place)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Ins = pd.DataFrame(clm)

# %%
Map_Ins.to_csv("Map_Ins.csv", encoding='utf-8', index=False)

# %%
Map_Ins
# Out:
#                            State                           District  Year  \
# 0      andaman-&-nicobar-islands             south andaman district  2020
# 1      andaman-&-nicobar-islands                  nicobars district  2020
# 2      andaman-&-nicobar-islands  north and middle andaman district  2020
# 3      andaman-&-nicobar-islands             south andaman district  2020
# 4      andaman-&-nicobar-islands                  nicobars district  2020
# ...                          ...                                ...   ...
# 10823                west-bengal                     nadia district  2023
# 10824                west-bengal                   birbhum district  2023
# 10825                west-bengal           purba medinipur district  2023
# 10826                west-bengal                    maldah district  2023
# 10827                west-bengal                 darjiling district  2023
#
#        Quater  Insurance_count  Insurance_amount
# ...

# %%
# Top-Transaction
path = "pulse/data/top/transaction/country/india/state/"

Top_state_list = os.listdir(path)

clm={'State':[], 'District':[], "Pincode":[], 'Year':[], 'Quater':[], 'Trans_dist_count':[], 'Trans_dist_amount':[], 'Trans_pincode_count':[], 'Trans_pincode_amount':[]}

for i in Top_state_list:
    p_i = path + i + "/"
    Top_yr_list = os.listdir(p_i)
    for j in Top_yr_list:
        p_j = p_i + j + "/"
        Top_Q_list = os.listdir(p_j)
        for k in Top_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            # for z in D['data']:
                # state = D['data']['states'][0]['entityName']
                # s_count = z['states'][0]['metric']['count']
                # s_amount = z['states'][0]['metric']['amount']
            district = D['data']["districts"][0]['entityName']
            d_count = D['data']["districts"][0]['metric']['count']
            d_amount = D['data']["districts"][0]['metric']['amount']
            pincode = D['data']["pincodes"][0]['entityName']
            p_count = D['data']["pincodes"][0]['metric']['count']
            p_amount = D['data']["pincodes"][0]['metric']['amount']
            clm['Trans_dist_count'].append(d_count)
            clm['Trans_dist_amount'].append(d_amount)
            clm['Trans_pincode_count'].append(p_count)
            clm['Trans_pincode_amount'].append(p_amount)
            clm['Pincode'].append(pincode)
            clm['District'].append(district)
            clm['State'].append(i)
            clm['Year'].append(j)
            clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Trans = pd.DataFrame(clm)

# %%
Top_Trans.to_csv("Top_Trans.csv", encoding='utf-8', index=False)

# %%
Top_Trans
# Out:
#                          State                    District Pincode  Year  \
# 0    andaman-&-nicobar-islands               south andaman  744101  2018
# 1    andaman-&-nicobar-islands               south andaman  744101  2018
# 2    andaman-&-nicobar-islands               south andaman  744101  2018
# 3    andaman-&-nicobar-islands               south andaman  744101  2018
# 4    andaman-&-nicobar-islands               south andaman  744103  2019
# ..                         ...                         ...     ...   ...
# 859                west-bengal                     kolkata  700039  2022
# 860                west-bengal  north twenty four parganas  700156  2023
# 861                west-bengal  north twenty four parganas  700156  2023
# 862                west-bengal  north twenty four parganas  700156  2023
# 863                west-bengal  north twenty four parganas  700156  2023
#
#      Quater  Trans_dist_count  Trans_dist_amount  Trans_pincode_count  \
# ...

# %%
# Top-Users
path = "pulse/data/top/user/country/india/state/"

Top_state_list = os.listdir(path)

clm={'State':[], 'District':[], "Pincode":[], 'Year':[], 'Quater':[], 'User_dist_count':[], 'User_pincode_count':[]}

for i in Top_state_list:
    p_i = path + i + "/"
    Top_yr_list = os.listdir(p_i)
    for j in Top_yr_list:
        p_j = p_i + j + "/"
        Top_Q_list = os.listdir(p_j)
        for k in Top_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            # for z in D['data']:
                # state = D['data']['states'][0]['name']
                # s_users = z['states'][0]['registeredUsers']
            district = D['data']["districts"][0]['name']
            d_users = D['data']["districts"][0]['registeredUsers']
            pincode = D['data']["pincodes"][0]['name']
            p_users = D['data']["pincodes"][0]['registeredUsers']
            clm['User_dist_count'].append(d_users)
            clm['User_pincode_count'].append(p_users)
            clm['Pincode'].append(pincode)
            clm['District'].append(district)
            clm['State'].append(i)
            clm['Year'].append(j)
            clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Users = pd.DataFrame(clm)

# %%
Top_Users.to_csv("Top_Users.csv", encoding='utf-8', index=False)

# %%
Top_Users
# Out:
#                          State                    District Pincode  Year  \
# 0    andaman-&-nicobar-islands               south andaman  744103  2018
# 1    andaman-&-nicobar-islands               south andaman  744103  2018
# 2    andaman-&-nicobar-islands               south andaman  744103  2018
# 3    andaman-&-nicobar-islands               south andaman  744103  2018
# 4    andaman-&-nicobar-islands               south andaman  744103  2019
# ..                         ...                         ...     ...   ...
# 859                west-bengal  north twenty four parganas  711101  2022
# 860                west-bengal  north twenty four parganas  711101  2023
# 861                west-bengal  north twenty four parganas  711101  2023
# 862                west-bengal  north twenty four parganas  711101  2023
# 863                west-bengal  north twenty four parganas  711101  2023
#
#      Quater  User_dist_count  User_pincode_count
# ...

# %%
# Top-Insurance
path = "pulse/data/top/insurance/country/india/state/"

Top_state_list = os.listdir(path)

clm={'State':[], 'District':[], "Pincode":[], 'Year':[], 'Quater':[], 'Ins_dist_count':[], 'Ins_dist_amount':[], 'Ins_pincode_count':[], 'Ins_pincode_amount':[]}

for i in Top_state_list:
    p_i = path + i + "/"
    Top_yr_list = os.listdir(p_i)
    for j in Top_yr_list:
        p_j = p_i + j + "/"
        Top_Q_list = os.listdir(p_j)
        for k in Top_Q_list:
            p_k = p_j + k
            Data = open(p_k,'r')
            D = json.load(Data)
            if len(D['data']["districts"]) != 0:
                # state = D['data']['states'][0]['entityName']
                # s_count = D['data']['states'][0]['metric']["count"]
                # s_amount = D['data']['states'][0]['metric']["amount"]
                # print(D['data']["districts"][0]['entityName'])
                district = D['data']["districts"][0]['entityName']
                d_count = D['data']['districts'][0]['metric']["count"]
                d_amount = D['data']['districts'][0]['metric']["amount"]
                pincode = D['data']["pincodes"][0]['entityName']
                p_count = D['data']['pincodes'][0]['metric']["count"]
                p_amount = D['data']['pincodes'][0]['metric']["amount"]
                clm['Ins_dist_count'].append(d_count)
                clm['Ins_dist_amount'].append(d_amount)
                clm['Ins_pincode_count'].append(p_count)
                clm['Ins_pincode_amount'].append(p_amount)
                clm['Pincode'].append(pincode)
                clm['District'].append(district)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Ins = pd.DataFrame(clm)
# Out:
# {'states': None, 'districts': [{'entityName': 'nicobars', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 565.0}}, {'entityName': 'south andaman', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 795.0}}], 'pincodes': [{'entityName': '744301', 'metric': {'type': 'TOTAL', 'count': 3, 'amount': 565.0}}, {'entityName': '744104', 'metric': {'type': 'TOTAL', 'count': 2, 'amount': 513.0}}, {'entityName': '744101', 'metric': {'type': 'TOTAL', 'count': 1, 'amount': 282.0}}]}
# ...

# %%
Top_Ins.to_csv("Top_Ins.csv", encoding='utf-8', index=False)

# %%
Top_Ins
# Out:
#                          State                    District Pincode  Year  \
# 0    andaman-&-nicobar-islands                    nicobars  744301  2020
# 1    andaman-&-nicobar-islands               south andaman  744112  2020
# 2    andaman-&-nicobar-islands               south andaman  744105  2020
# 3    andaman-&-nicobar-islands               south andaman  744105  2021
# 4    andaman-&-nicobar-islands               south andaman  744103  2021
# ..                         ...                         ...     ...   ...
# 533                west-bengal  north twenty four parganas  711101  2022
# 534                west-bengal  north twenty four parganas  711101  2023
# 535                west-bengal  north twenty four parganas  700039  2023
# 536                west-bengal  north twenty four parganas  700091  2023
# 537                west-bengal  north twenty four parganas  700156  2023
#
#      Quater  Ins_dist_count  Ins_dist_amount  Ins_pincode_count  \
# ...

# %%
Top_Trans_States = Top_Trans.groupby(["State", "Year", "Quater"])["Trans_dist_count"].sum()
Top_Trans_States
# Out:
# State                      Year  Quater
# andaman-&-nicobar-islands  2018  1              5688
#                                  2              9395
#                                  3             13511
#                                  4             20136
#                            2019  1             25683
#                                              ...
# west-bengal                2022  4         151040298
#                            2023  1          82336235
#                                  2          96628528
#                                  3         113910456
#                                  4         128343164
# Name: Trans_dist_count, Length: 864, dtype: int64

# %%
Top_Trans.pivot_table(
    ["Trans_dist_count"],
    ["State", "Year", "Quater"],
    aggfunc="sum",
)
# Out:
#                                        Trans_dist_count
# State                     Year Quater
# andaman-&-nicobar-islands 2018 1                   5688
#                                2                   9395
#                                3                  13511
#                                4                  20136
#                           2019 1                  25683
# ...                                                 ...
# west-bengal               2022 4              151040298
#                           2023 1               82336235
#                                2               96628528
#                                3              113910456
#                                4              128343164
#
# [864 rows x 1 columns]

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
Agg_Trans.describe()
# Out:
#             Quater  Transaction_count  Transaction_amount
# count  4314.000000       4.314000e+03        4.314000e+03
# mean      2.500927       3.152081e+07        5.004584e+10
# std       1.118163       1.131400e+08        2.029985e+11
# min       1.000000       2.000000e+00        3.439721e+01
# 25%       2.000000       4.968825e+04        3.318150e+07
# 50%       3.000000       4.315830e+05        3.463892e+08
# 75%       4.000000       9.046208e+06        8.074255e+09
# max       4.000000       1.646497e+09        2.456913e+12

# %%
Agg_Trans.describe(include=["object", "bool"])
# Out:
#                             State  Year          Transaction_type
# count                        4314  4314                      4314
# unique                         36     6                         5
# top     andaman-&-nicobar-islands  2021  Recharge & bill payments
# freq                          120   720                       864
